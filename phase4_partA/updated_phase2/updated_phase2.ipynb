# %% [markdown]
# # **Phase 2 (Group 29) - Data Staging**
# Émilie Brazeau (300209120), Nicholas Gin (300107597), Gordon Tang (300132939)
#
# Link to Google Colab: https://colab.research.google.com/drive/1uW1q-00w0KnWrTeEMgB16Uaf-1XaOG_X?usp=sharing

# %%
import pandas as pd
from google.colab import files

import nltk
nltk.download('stopwords')
nltk.download("wordnet")
nltk.download("omw-1.4")
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer

import re
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...

# %% [markdown]
# # **Disneyland Reviews Dataset**
# # Extract

# %%
# Loading the data
url='https://drive.google.com/file/d/1atEjlCz6cNs4_bKLd2Mwe-W-MIKwz3AU/view?usp=sharing'
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
df_dis = pd.read_csv(url, encoding='cp1252')

df_dis.head(9)
# Out:
#    Review_ID  Rating Year_Month     Reviewer_Location  \
# 0  670772142       4     2019-4             Australia
# 1  670682799       4     2019-5           Philippines
# 2  670623270       4     2019-4  United Arab Emirates
# 3  670607911       4     2019-4             Australia
# 4  670607296       4     2019-4        United Kingdom
# 5  670591897       3     2019-4             Singapore
# 6  670585330       5     2019-4                 India
# 7  670574142       3     2019-3              Malaysia
# 8  670571027       2     2019-4             Australia
#
#                                          Review_Text               Branch
# 0  If you've ever been to Disneyland anywhere you...  Disneyland_HongKong
# 1  Its been a while since d last time we visit HK...  Disneyland_HongKong
# 2  Thanks God it wasn   t too hot or too humid wh...  Disneyland_HongKong
# 3  HK Disneyland is a great compact park. Unfortu...  Disneyland_HongKong
# 4  the location is not in the city, took around 1...  Disneyland_HongKong
# 5  Have been to Disney World, Disneyland Anaheim ...  Disneyland_HongKong
# 6  Great place! Your day will go by and you won't...  Disneyland_HongKong
# 7  Think of it as an intro to Disney magic for th...  Disneyland_HongKong
# 8  Feel so let down with this place,the Disneylan...  Disneyland_HongKong

# %%
print(df_dis.dtypes)
# Out:
# Review_ID             int64
# Rating                int64
# Year_Month           object
# Reviewer_Location    object
# Review_Text          object
# Branch               object
# dtype: object

# %% [markdown]
# # Transform

# %% [markdown]
# **Clean up data**

# %%
# Strip whitespaces and extra blank spaces in the Review Texts.
def strip(text):
    # Remove any leading/trailing whitespace
    text = text.strip()
    # Replace any runs of whitespace with a single space
    text = re.sub(r'\s+', ' ', text)
    # Add a space after any punctuation marks (except apostrophes or if already separated by whitespace)
    # Do this for consistency
    text = re.sub(r'(?<=[^\s\w])|(?=[^\s\w])', ' ', text)
    # Remove any double spaces
    text = re.sub(r'\s\s+', ' ', text)
    return text

# Apply the strip function to the 'Review_Text' column
df_dis['Review_Text'] = df_dis['Review_Text'].apply(strip)
# Normalizing the Review Texts (decapitalizing the Review Texts).
df_dis['Review_Text'] = df_dis['Review_Text'].str.lower()
# Remove unicode characters.
pattern = r'[^a-z0-9\s]'
df_dis['Review_Text'] = df_dis['Review_Text'].str.replace(pattern, '', regex=True)
df_dis['Review_Text'] = df_dis['Review_Text'].str.replace(r"(@\[\w+\])|(#\w+)|(\w+:\/\/\S+)|^rt|http.+?", "", regex=True)
# Remove stop words.
stop_words = stopwords.words('english')
df_dis['Review_Text'] = df_dis['Review_Text'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop_words)]))
# Lemmatize words.
lemmatizer = WordNetLemmatizer()
df_dis['Review_Text'] = df_dis['Review_Text'].apply(lambda x: ' '.join([lemmatizer.lemmatize(word) for word in x.split()]))

# For formatting consistency (with the Universal Studios Reviews dataset), update the formatting of each Disneyland branch.
df_dis['Branch'] = df_dis['Branch'].replace('Disneyland_HongKong', 'Disneyland Hong Kong').replace('Disneyland_Paris', 'Disneyland Paris').replace('Disneyland_California', 'Disneyland California')

df_dis.head(20)
# Out:
#     Review_ID  Rating Year_Month     Reviewer_Location  \
# 0   670772142       4     2019-4             Australia
# 1   670682799       4     2019-5           Philippines
# 2   670623270       4     2019-4  United Arab Emirates
# 3   670607911       4     2019-4             Australia
# 4   670607296       4     2019-4        United Kingdom
# 5   670591897       3     2019-4             Singapore
# 6   670585330       5     2019-4                 India
# 7   670574142       3     2019-3              Malaysia
# 8   670571027       2     2019-4             Australia
# 9   670570869       5     2019-3                 India
# 10  670443403       5     2019-4         United States
# 11  670435886       5     2019-4                Canada
# 12  670376905       4     2019-4             Australia
# 13  670324965       5     2019-4           Philippines
# 14  670274554       5     2018-9             Australia
# 15  670205135       3     2019-1        United Kingdom
# 16  670199487       4     2019-4       Myanmar (Burma)
# 17  670129921       3     2019-4        United Kingdom
# 18  670099231       4     2019-4             Australia
# 19  670033848       5    2018-11             Hong Kong
#
#                                           Review_Text                Branch
# 0   ever disneyland anywhere find disneyland hong ...  Disneyland Hong Kong
# 1   since last time visit hk disneyland yet time s...  Disneyland Hong Kong
# 2   thanks god hot humid visiting park otherwise w...  Disneyland Hong Kong
# 3   hk disneyland great compact park unfortunately...  Disneyland Hong Kong
# 4   location city took around 1 hour kowlon kid li...  Disneyland Hong Kong
# 5   disney world disneyland anaheim tokyo disneyla...  Disneyland Hong Kong
# 6   great place day go even know obviously went da...  Disneyland Hong Kong
# 7   think intro disney magic little one almost att...  Disneyland Hong Kong
# 8   feel let place disneyland train fantastic get ...  Disneyland Hong Kong
# 9   go talking disneyland whatever say le disneyla...  Disneyland Hong Kong
# 10  disneyland never cease amaze disneyland florid...  Disneyland Hong Kong
# 11  spent day grown kid admit great time seems kid...  Disneyland Hong Kong
# 12  spend two day second day went early went strai...  Disneyland Hong Kong
# 13  indeed happiest place earth family really fun ...  Disneyland Hong Kong
# 14  place huge definately need one day 3 child age...  Disneyland Hong Kong
# 15  brought ticket left got 2 day le price 1 visit...  Disneyland Hong Kong
# 16  huge enough visit one day 2 day pas scene amaz...  Disneyland Hong Kong
# 17  around 60 per person want eat drink point cost...  Disneyland Hong Kong
# 18  disneyland need reviewing place speaks however...  Disneyland Hong Kong
# 19  nothing say except become child step inside di...  Disneyland Hong Kong

# %% [markdown]
# **Drop unrequired columns, remove null values and split columns where necessary**

# %%
# Split the 'Year_Month' column into two separate columns for the 'Year' and 'Month', respectively.
# Values in the 'Year_Month' column are in one of two formats: yyyy-mm or yyyy-m (with yyyy representing a four digit year,
# mm representing a two digit month, m representing a one digit month).
df_dis[['Year', 'Month']] = df_dis['Year_Month'].str.split('-', expand=True)

# Replace all 'missing' values (note these are not null values) in the 'Year' column with -1.
df_dis['Year'] = df_dis['Year'].replace('missing', '-1')
# Set the 'Year' column type to int.
df_dis['Year'] = df_dis['Year'].astype(int)

# Replace all null values in the 'Month' column with -1.
df_dis['Month'] = df_dis['Month'].fillna(-1)
# Set the 'Month' column type to int.
df_dis['Month'] = df_dis['Month'].astype(int)

# Remove any entries in the dataset with null values (we are not able to add this information from other datasets).
df_dis = df_dis[df_dis['Year'] != -1]
df_dis = df_dis[df_dis['Month'] != -1]

# Create 'Quarter' column.
df_dis['Quarter'] = pd.to_datetime(df_dis['Month'], format='%m').dt.quarter

# Remove rows with empty Review_Texts.
df_dis = df_dis[df_dis['Review_Text'] != '']

# Drop columns that are not found in the Universal Studios Reviews dataset, as well as the 'Year_Month' column, since it is no longer required.
df_dis.drop(columns = ['Year_Month', 'Reviewer_Location', 'Review_ID'])

# Re-order the columns in the dataset.
df_dis = df_dis.reindex(columns=['Review_Text', 'Rating', 'Month', 'Quarter', 'Year', 'Branch'])

df_dis.head(30)
# Out:
#                                           Review_Text  Rating  Month  Quarter  \
# 0   ever disneyland anywhere find disneyland hong ...       4      4        2
# 1   since last time visit hk disneyland yet time s...       4      5        2
# 2   thanks god hot humid visiting park otherwise w...       4      4        2
# 3   hk disneyland great compact park unfortunately...       4      4        2
# 4   location city took around 1 hour kowlon kid li...       4      4        2
# 5   disney world disneyland anaheim tokyo disneyla...       3      4        2
# 6   great place day go even know obviously went da...       5      4        2
# 7   think intro disney magic little one almost att...       3      3        1
# 8   feel let place disneyland train fantastic get ...       2      4        2
# 9   go talking disneyland whatever say le disneyla...       5      3        1
# 10  disneyland never cease amaze disneyland florid...       5      4        2
# 11  spent day grown kid admit great time seems kid...       5      4        2
# 12  spend two day second day went early went strai...       4      4        2
# 13  indeed happiest place earth family really fun ...       5      4        2
# 14  place huge definately need one day 3 child age...       5      9        3
# 15  brought ticket left got 2 day le price 1 visit...       3      1        1
# 16  huge enough visit one day 2 day pas scene amaz...       4      4        2
# 17  around 60 per person want eat drink point cost...       3      4        2
# 18  disneyland need reviewing place speaks however...       4      4        2
# 19  nothing say except become child step inside di...       5     11        4
# 20  bought 2 day tourist ticket via klook made bet...       5      4        2
# 21  first really big disneyland fan live 20 minute...       3      4        2
# 22  mickey wounderous book great kid love new ant ...       3      4        2
# 23  hong kong disneyland twice even new attraction...       3      4        2
# 24  go early want photo signboard mickey donald du...       5      4        2
# 25  disneyland world generic apart language differ...       3      4        2
# 26  second trip first 3 year ago smallish disneyla...       3      4        2
# 27  hong kong disneyland time already still want c...       5     12        4
# 28  visited wednesday arrived opening found queue ...       5      4        2
# 29  need say home disney disneyland anaheim hk dis...       3      4        2
#
#     Year                Branch
# 0   2019  Disneyland Hong Kong
# 1   2019  Disneyland Hong Kong
# 2   2019  Disneyland Hong Kong
# 3   2019  Disneyland Hong Kong
# 4   2019  Disneyland Hong Kong
# 5   2019  Disneyland Hong Kong
# 6   2019  Disneyland Hong Kong
# 7   2019  Disneyland Hong Kong
# 8   2019  Disneyland Hong Kong
# 9   2019  Disneyland Hong Kong
# 10  2019  Disneyland Hong Kong
# 11  2019  Disneyland Hong Kong
# 12  2019  Disneyland Hong Kong
# 13  2019  Disneyland Hong Kong
# 14  2018  Disneyland Hong Kong
# 15  2019  Disneyland Hong Kong
# 16  2019  Disneyland Hong Kong
# 17  2019  Disneyland Hong Kong
# 18  2019  Disneyland Hong Kong
# 19  2018  Disneyland Hong Kong
# 20  2019  Disneyland Hong Kong
# 21  2019  Disneyland Hong Kong
# 22  2019  Disneyland Hong Kong
# 23  2019  Disneyland Hong Kong
# 24  2019  Disneyland Hong Kong
# 25  2019  Disneyland Hong Kong
# 26  2019  Disneyland Hong Kong
# 27  2018  Disneyland Hong Kong
# 28  2019  Disneyland Hong Kong
# 29  2019  Disneyland Hong Kong

# %% [markdown]
# **Remove noisy data and duplicates**

# %%
df_dis = df_dis[df_dis['Review_Text'] != "activex vt error"] # Noisy data
df_dis = df_dis.drop_duplicates(keep = 'first') # Drop duplicates

# %% [markdown]
# **Generate measures/facts**

# %%
# Define a function to calculate the percentage of ratings in each group
def rating_percentages(group):
    # Calculate the percentage of positive ratings by counting the number of ratings that are 4 or 5, and dividing by the total number of ratings in the group
    positive = group[group['Rating'] >= 4]['Rating'].count() / group['Rating'].count()
    # Calculate the percentage of mixed ratings by counting the number of ratings that are 3, and dividing by the total number of ratings in the group
    mixed = group[group['Rating'] == 3]['Rating'].count() / group['Rating'].count()
    # Calculate the percentage of negative ratings by counting the number of ratings that are 1 or 2, and dividing by the total number of ratings in the group
    negative = group[group['Rating'] <= 2]['Rating'].count() / group['Rating'].count()
    # Return a Pandas Series object with the calculated percentages as values and the column names as the index
    return pd.Series({'Monthly % of Positive Reviews': positive * 100, 'Monthly % of Mixed Reviews': mixed * 100, 'Monthly % of Negative Reviews': negative * 100})

percentages_dis = df_dis.groupby(['Branch', 'Year', 'Month']).apply(rating_percentages)

percentages_dis
# Out:
#                                   Monthly % of Positive Reviews  \
# Branch                Year Month
# Disneyland California 2010 4                         100.000000
#                            5                         100.000000
#                            6                          60.000000
#                            7                          75.000000
#                            8                          80.000000
# ...                                                         ...
# Disneyland Paris      2018 12                         61.206897
#                       2019 1                          73.770492
#                            2                          74.576271
#                            3                          61.764706
#                            4                          52.941176
#
#                                   Monthly % of Mixed Reviews  \
# Branch                Year Month
# Disneyland California 2010 4                        0.000000
#                            5                        0.000000
#                            6                       20.000000
#                            7                       25.000000
#                            8                        0.000000
# ...                                                      ...
# Disneyland Paris      2018 12                      17.241379
#                       2019 1                       11.475410
#                            2                       13.559322
#                            3                       16.176471
#                            4                       22.058824
#
#                                   Monthly % of Negative Reviews
# Branch                Year Month
# Disneyland California 2010 4                           0.000000
#                            5                           0.000000
#                            6                          20.000000
#                            7                           0.000000
#                            8                          20.000000
# ...                                                         ...
# Disneyland Paris      2018 12                         21.551724
#                       2019 1                          14.754098
#                            2                          11.864407
#                            3                          22.058824
#                            4                          25.000000
#
# [326 rows x 3 columns]

# %%
df_dis = df_dis.merge(percentages_dis, how='outer', on=['Branch', 'Year', 'Month'])

df_dis.head(300)
# Out:
#                                            Review_Text  Rating  Month  \
# 0    ever disneyland anywhere find disneyland hong ...       4      4
# 1    thanks god hot humid visiting park otherwise w...       4      4
# 2    hk disneyland great compact park unfortunately...       4      4
# 3    location city took around 1 hour kowlon kid li...       4      4
# 4    disney world disneyland anaheim tokyo disneyla...       3      4
# ..                                                 ...     ...    ...
# 295  every disney park world one may favorite 4 vis...       5     11
# 296  fl check sadly think better spending second da...       3     11
# 297  simply best day hong kong disney read negative...       5     11
# 298  went week day would recommend even hundred peo...       4     11
# 299  great park easily rode everything wanted one d...       5     11
#
#      Quarter  Year                Branch  Monthly % of Positive Reviews  \
# 0          2  2019  Disneyland Hong Kong                      78.688525
# 1          2  2019  Disneyland Hong Kong                      78.688525
# 2          2  2019  Disneyland Hong Kong                      78.688525
# 3          2  2019  Disneyland Hong Kong                      78.688525
# 4          2  2019  Disneyland Hong Kong                      78.688525
# ..       ...   ...                   ...                            ...
# 295        4  2018  Disneyland Hong Kong                      75.806452
# 296        4  2018  Disneyland Hong Kong                      75.806452
# 297        4  2018  Disneyland Hong Kong                      75.806452
# 298        4  2018  Disneyland Hong Kong                      75.806452
# 299        4  2018  Disneyland Hong Kong                      75.806452
#
#      Monthly % of Mixed Reviews  Monthly % of Negative Reviews
# 0                     18.032787                       3.278689
# 1                     18.032787                       3.278689
# 2                     18.032787                       3.278689
# 3                     18.032787                       3.278689
# 4                     18.032787                       3.278689
# ..                          ...                            ...
# 295                   14.516129                       9.677419
# 296                   14.516129                       9.677419
# 297                   14.516129                       9.677419
# 298                   14.516129                       9.677419
# 299                   14.516129                       9.677419
#
# [300 rows x 9 columns]

# %%
print(df_dis.isnull().sum())
# Out:
# Review_Text                      0
# Rating                           0
# Month                            0
# Quarter                          0
# Year                             0
# Branch                           0
# Monthly % of Positive Reviews    0
# Monthly % of Mixed Reviews       0
# Monthly % of Negative Reviews    0
# dtype: int64

# %% [markdown]
# # **Universal Studios Reviews Dataset**
# # Extract

# %%
# Loading the data
url='https://drive.google.com/file/d/1Avu5OYvmN8kWFzICK3_KE13Ob1V0uPwP/view?usp=sharing'
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
df_uni = pd.read_csv(url, encoding='UTF-8')

df_uni
# Out:
#                    reviewer  rating       written_date  \
# 0                   Kelly B     2.0       May 30, 2021
# 1                       Jon     1.0       May 30, 2021
# 2                   Nerdy P     2.0       May 30, 2021
# 3                 ran101278     4.0       May 29, 2021
# 4           tammies20132015     5.0       May 28, 2021
# ...                     ...     ...                ...
# 50899                vinz20     4.0     March 29, 2010
# 50900               betty l     4.0     March 29, 2010
# 50901             spoonos65     4.0     March 28, 2010
# 50902  HeatSeekerWrexham_UK     4.0     March 22, 2010
# 50903          sc_myinitial     5.0  February 24, 2010
#
#                                                    title  \
# 0      Universal is a complete Disaster - stick with ...
# 1                                   Food is hard to get.
# 2                                           Disappointed
# 3                                             My opinion
# 4                      The Bourne Stuntacular...MUST SEE
# ...                                                  ...
# 50899                           I'll Be Back Only If ...
# 50900             Universal Studios Singapore Experience
# 50901                 Impressive but not quite finished!
# 50902                       Small but beautifully marked
# 50903                            Excellent Sneak Preview
#
#                                              review_text  \
# 0      We went to Universal over Memorial Day weekend...
# 1      The food service is horrible. I’m not reviewin...
# 2      I booked this vacation mainly to ride Hagrid m...
# 3      When a person tries the test seat for the ride...
# 4      Ok, I can't stress enough to anyone and everyo...
# ...                                                  ...
# 50899  This is my first visit to a Universal Studio t...
# 50900  We finally visited Singapore's very first them...
# 50901  We visited during the first week of its 'soft ...
# 50902  We visited on the 3rd day of the 'soft' openin...
# 50903  My group managed to get the tickets for the 16...
#
#                             branch
# 0        Universal Studios Florida
# 1        Universal Studios Florida
# 2        Universal Studios Florida
# 3        Universal Studios Florida
# 4        Universal Studios Florida
# ...                            ...
# 50899  Universal Studios Singapore
# 50900  Universal Studios Singapore
# 50901  Universal Studios Singapore
# 50902  Universal Studios Singapore
# 50903  Universal Studios Singapore
#
# [50904 rows x 6 columns]

# %%
print(df_uni.dtypes)
# Out:
# reviewer         object
# rating          float64
# written_date     object
# title            object
# review_text      object
# branch           object
# dtype: object

# %% [markdown]
# # Transform

# %% [markdown]
# **Clean up data**

# %%
# Clean up all entries in the review_text column.

# Strip whitespaces and extra blank space in the review texts.
df_uni['review_text'] = df_uni['review_text'].apply(strip)
# Normalizing the Review Texts (decapitalizing the Review Texts).
df_uni['review_text'] = df_uni['review_text'].str.lower()
# Remove unicode characters.
df_uni['review_text'] = df_uni['review_text'].str.replace(pattern, '', regex=True)
df_uni['review_text'] = df_uni['review_text'].str.replace(r"(@\[\w+\])|(#\w+)|(\w+:\/\/\S+)|^rt|http.+?", "", regex=True)
# Remove stop words.
df_uni['review_text'] = df_uni['review_text'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop_words)]))
# Stem words.
df_uni['review_text'] = df_uni['review_text'].apply(lambda x: ' '.join([lemmatizer.lemmatize(word) for word in x.split()]))

# Set the ratings in the 'rating' column to type int to be consistent with the Disneyland Reviews dataset.
df_uni['rating'] = df_uni['rating'].astype(int)

# Reformat column names in the Universal Studios Reviews dataset to match the columns in the Disneyland Reviews dataset.
# Note that we are only reformatting columns we will be keeping; we will be dropping columns we don't need in the next step.
df_uni = df_uni.rename({'rating': 'Rating', 'review_text': 'Review_Text', 'branch': 'Branch'}, axis=1)

df_uni.head(20)
# Out:
#            reviewer  Rating  written_date  \
# 0           Kelly B       2  May 30, 2021
# 1               Jon       1  May 30, 2021
# 2           Nerdy P       2  May 30, 2021
# 3         ran101278       4  May 29, 2021
# 4   tammies20132015       5  May 28, 2021
# 5              John       1  May 28, 2021
# 6      annapN7702ZW       2  May 27, 2021
# 7             Deb P       2  May 27, 2021
# 8           Chuck N       1  May 27, 2021
# 9               Jen       4  May 26, 2021
# 10           Paul S       1  May 26, 2021
# 11         Mandee L       5  May 25, 2021
# 12           Kate Z       2  May 25, 2021
# 13       Kimberly T       1  May 24, 2021
# 14          Nancy C       5  May 24, 2021
# 15       SunilnRiss       5  May 22, 2021
# 16        Natasha L       5  May 19, 2021
# 17          khali m       1  May 19, 2021
# 18       Linkstrips       4  May 19, 2021
# 19       Aleisha523       1  May 19, 2021
#
#                                                 title  \
# 0   Universal is a complete Disaster - stick with ...
# 1                                Food is hard to get.
# 2                                        Disappointed
# 3                                          My opinion
# 4                   The Bourne Stuntacular...MUST SEE
# 5                              This is not a vacation
# 6                                       Expected More
# 7                                   Disapointing.....
# 8         Greed makes for a terrible guest experience
# 9                     Good first time visit with kids
# 10                       Same old Orlando experience.
# 11                                Family Vacation Fun
# 12  Crowded, unhelpful staff, and difficult to get...
# 13      Parking and Guest Services TERRIBLE!!!!!!!!!!
# 14                                 Excellent Vacation
# 15  Stay at one of 3 resorts that offer EXPRESS PA...
# 16                          Despite the Circumstances
# 17                                              AWFUL
# 18                                        Over priced
# 19  Don’t buy a package with one of their partner ...
#
#                                           Review_Text  \
# 0   went universal memorial day weekend total trai...
# 1   food service horrible reviewing food wait time...
# 2   booked vacation mainly ride hagrid motorcycle ...
# 3   person try test seat ride get green light go l...
# 4   ok stress enough anyone everyone go universal ...
# 5   worst experience ever ride outdated whole plac...
# 6   expected alot waiting around lack staffing pri...
# 7   4th trip daughter universal unfortunately disa...
# 8   universal one thing disney everything disney w...
# 9   spent 6 night site sapphire fall family 6 2 ad...
# 10  literally standing line hagrid thing scheduled...
# 11  universal adventure park best two went impress...
# 12  disney tell much returned one day visit univer...
# 13  went city walk due quadriplegic son nothing ch...
# 14  age ride restaurant lot photo opportunity fant...
# 15  park always awesome vet pretty crowded harry p...
# 16  humid windy wear mask universal still disappoi...
# 17  rude worker yelled ton people multiple ride br...
# 18  went park wednesday got early early pas get ah...
# 19  first visit universal disney passholders year ...
#
#                        Branch
# 0   Universal Studios Florida
# 1   Universal Studios Florida
# 2   Universal Studios Florida
# 3   Universal Studios Florida
# 4   Universal Studios Florida
# 5   Universal Studios Florida
# 6   Universal Studios Florida
# 7   Universal Studios Florida
# 8   Universal Studios Florida
# 9   Universal Studios Florida
# 10  Universal Studios Florida
# 11  Universal Studios Florida
# 12  Universal Studios Florida
# 13  Universal Studios Florida
# 14  Universal Studios Florida
# 15  Universal Studios Florida
# 16  Universal Studios Florida
# 17  Universal Studios Florida
# 18  Universal Studios Florida
# 19  Universal Studios Florida

# %% [markdown]
# **Drop unrequired columns and split columns where necessary**

# %%
# To be consistent with the Disneyland Reviews dataset, split the 'written_date' column into two separate columns for the 'Year' and 'Month', respectively.
# We will not be saving the day from the date.
df_uni['written_date'] = pd.to_datetime(df_uni['written_date'])
df_uni['Month'] = df_uni['written_date'].dt.month
df_uni['Year'] = df_uni['written_date'].dt.year

# Create 'Quarter' column.
df_uni['Quarter'] = pd.to_datetime(df_uni['Month'], format='%m').dt.quarter

# Remove rows with empty Review_Texts.
df_uni = df_uni[df_uni['Review_Text'] != '']

# Drop columns that are not found in the Disneyland Reviews dataset, as well as the 'written_date' column, since it is no longer required.
df_uni = df_uni.drop(columns = ['reviewer', 'written_date', 'title'])

# Re-order the columns in the dataset.
df_uni = df_uni.reindex(columns=['Review_Text', 'Rating', 'Month', 'Quarter', 'Year', 'Branch'])

df_uni.head(30)
# Out:
#                                           Review_Text  Rating  Month  Quarter  \
# 0   went universal memorial day weekend total trai...       2      5        2
# 1   food service horrible reviewing food wait time...       1      5        2
# 2   booked vacation mainly ride hagrid motorcycle ...       2      5        2
# 3   person try test seat ride get green light go l...       4      5        2
# 4   ok stress enough anyone everyone go universal ...       5      5        2
# 5   worst experience ever ride outdated whole plac...       1      5        2
# 6   expected alot waiting around lack staffing pri...       2      5        2
# 7   4th trip daughter universal unfortunately disa...       2      5        2
# 8   universal one thing disney everything disney w...       1      5        2
# 9   spent 6 night site sapphire fall family 6 2 ad...       4      5        2
# 10  literally standing line hagrid thing scheduled...       1      5        2
# 11  universal adventure park best two went impress...       5      5        2
# 12  disney tell much returned one day visit univer...       2      5        2
# 13  went city walk due quadriplegic son nothing ch...       1      5        2
# 14  age ride restaurant lot photo opportunity fant...       5      5        2
# 15  park always awesome vet pretty crowded harry p...       5      5        2
# 16  humid windy wear mask universal still disappoi...       5      5        2
# 17  rude worker yelled ton people multiple ride br...       1      5        2
# 18  went park wednesday got early early pas get ah...       4      5        2
# 19  first visit universal disney passholders year ...       1      5        2
# 20  went universal class field trip sucked 3 ride ...       2      5        2
# 21  universal studio three theme park 1 universal ...       2      5        2
# 22  great price great experience super easy get ti...       5      5        2
# 23  florida resident universal park many time year...       2      5        2
# 24  long time coming literally coming park since c...       5      5        2
# 25  universal multiple time always amazed make rea...       5      5        2
# 26  fast n furious supercharged ride disappointing...       1      5        2
# 27  cannot fault universal studio absolutely lovin...       5      5        2
# 28  harry potter world especially awesome simpson ...       5      5        2
# 29  many fun simulator ride love wizarding world o...       3      5        2
#
#     Year                     Branch
# 0   2021  Universal Studios Florida
# 1   2021  Universal Studios Florida
# 2   2021  Universal Studios Florida
# 3   2021  Universal Studios Florida
# 4   2021  Universal Studios Florida
# 5   2021  Universal Studios Florida
# 6   2021  Universal Studios Florida
# 7   2021  Universal Studios Florida
# 8   2021  Universal Studios Florida
# 9   2021  Universal Studios Florida
# 10  2021  Universal Studios Florida
# 11  2021  Universal Studios Florida
# 12  2021  Universal Studios Florida
# 13  2021  Universal Studios Florida
# 14  2021  Universal Studios Florida
# 15  2021  Universal Studios Florida
# 16  2021  Universal Studios Florida
# 17  2021  Universal Studios Florida
# 18  2021  Universal Studios Florida
# 19  2021  Universal Studios Florida
# 20  2021  Universal Studios Florida
# 21  2021  Universal Studios Florida
# 22  2021  Universal Studios Florida
# 23  2021  Universal Studios Florida
# 24  2021  Universal Studios Florida
# 25  2021  Universal Studios Florida
# 26  2021  Universal Studios Florida
# 27  2021  Universal Studios Florida
# 28  2021  Universal Studios Florida
# 29  2021  Universal Studios Florida

# %% [markdown]
# **Remove null values, noisy data and duplicates**

# %%
df_uni = df_uni.drop_duplicates(keep = 'first') # Drop duplicates

# Checking for null values in the Universal Studios dataset
print(df_uni.isnull().sum())
# Out:
# Review_Text    0
# Rating         0
# Month          0
# Quarter        0
# Year           0
# Branch         0
# dtype: int64

# %% [markdown]
# **Generate measures/facts**

# %%
percentages_uni = df_uni.groupby(['Branch', 'Year', 'Month']).apply(rating_percentages)

percentages_uni
# Out:
#                                         Monthly % of Positive Reviews  \
# Branch                      Year Month
# Universal Studios Florida   2002 10                          0.000000
#                             2003 3                         100.000000
#                                  4                         100.000000
#                                  6                         100.000000
#                                  7                         100.000000
# ...                                                               ...
# Universal Studios Singapore 2021 1                          33.333333
#                                  2                          71.428571
#                                  3                          66.666667
#                                  4                          71.428571
#                                  5                         100.000000
#
#                                         Monthly % of Mixed Reviews  \
# Branch                      Year Month
# Universal Studios Florida   2002 10                       0.000000
#                             2003 3                        0.000000
#                                  4                        0.000000
#                                  6                        0.000000
#                                  7                        0.000000
# ...                                                            ...
# Universal Studios Singapore 2021 1                       16.666667
#                                  2                       28.571429
#                                  3                        0.000000
#                                  4                        0.000000
#                                  5                        0.000000
#
#                                         Monthly % of Negative Reviews
# Branch                      Year Month
# Universal Studios Florida   2002 10                        100.000000
#                             2003 3                           0.000000
#                                  4                           0.000000
#                                  6                           0.000000
#                                  7                           0.000000
# ...                                                               ...
# Universal Studios Singapore 2021 1                          50.000000
#                                  2                           0.000000
#                                  3                          33.333333
#                                  4                          28.571429
#                                  5                           0.000000
#
# [477 rows x 3 columns]

# %%
df_uni = df_uni.merge(percentages_uni, how='outer', on=['Branch', 'Year', 'Month'])

df_uni.head(300)
# Out:
#                                            Review_Text  Rating  Month  \
# 0    went universal memorial day weekend total trai...       2      5
# 1    food service horrible reviewing food wait time...       1      5
# 2    booked vacation mainly ride hagrid motorcycle ...       2      5
# 3    person try test seat ride get green light go l...       4      5
# 4    ok stress enough anyone everyone go universal ...       5      5
# ..                                                 ...     ...    ...
# 295  purchased meal deal citywalk went margaritavil...       1     12
# 296  universal amazing job pandemic park clean ever...       5     12
# 297  absolutely adore place universal park definite...       5     12
# 298  family 5 two adult 8 6 6 750 spent one day 657...       2     12
# 299  due new virtual line discriminated smartphone ...       1     11
#
#      Quarter  Year                     Branch  Monthly % of Positive Reviews  \
# 0          2  2021  Universal Studios Florida                      36.734694
# 1          2  2021  Universal Studios Florida                      36.734694
# 2          2  2021  Universal Studios Florida                      36.734694
# 3          2  2021  Universal Studios Florida                      36.734694
# 4          2  2021  Universal Studios Florida                      36.734694
# ..       ...   ...                        ...                            ...
# 295        4  2020  Universal Studios Florida                      42.222222
# 296        4  2020  Universal Studios Florida                      42.222222
# 297        4  2020  Universal Studios Florida                      42.222222
# 298        4  2020  Universal Studios Florida                      42.222222
# 299        4  2020  Universal Studios Florida                      56.000000
#
#      Monthly % of Mixed Reviews  Monthly % of Negative Reviews
# 0                      8.163265                      55.102041
# 1                      8.163265                      55.102041
# 2                      8.163265                      55.102041
# 3                      8.163265                      55.102041
# 4                      8.163265                      55.102041
# ..                          ...                            ...
# 295                   11.111111                      46.666667
# 296                   11.111111                      46.666667
# 297                   11.111111                      46.666667
# 298                   11.111111                      46.666667
# 299                   12.000000                      32.000000
#
# [300 rows x 9 columns]

# %%
# Check for null values
print(df_uni.isnull().sum())
# Out:
# Review_Text                      0
# Rating                           0
# Month                            0
# Quarter                          0
# Year                             0
# Branch                           0
# Monthly % of Positive Reviews    0
# Monthly % of Mixed Reviews       0
# Monthly % of Negative Reviews    0
# dtype: int64

# %% [markdown]
# # Dataset Integration (Enrich Disneyland Reviews with Universal Studios Reviews)

# %%
# Merge the Disneyland Reviews and Universal Studios Reviews datasets.
df_reviews = pd.merge(df_dis, df_uni, how='outer', on=['Rating', 'Review_Text', 'Month', 'Quarter', 'Year', 'Branch', 'Monthly % of Positive Reviews', 'Monthly % of Mixed Reviews', 'Monthly % of Negative Reviews'])
df_reviews
# Out:
#                                              Review_Text  Rating  Month  \
# 0      ever disneyland anywhere find disneyland hong ...       4      4
# 1      thanks god hot humid visiting park otherwise w...       4      4
# 2      hk disneyland great compact park unfortunately...       4      4
# 3      location city took around 1 hour kowlon kid li...       4      4
# 4      disney world disneyland anaheim tokyo disneyla...       3      4
# ...                                                  ...     ...    ...
# 90875  first visit universal studio theme park went p...       4      3
# 90876  finally visited singapore first theme park uni...       4      3
# 90877  visited first week soft opening unfortunately ...       4      3
# 90878  visited 3rd day soft opening ticket sale limit...       4      3
# 90879  group managed get ticket 16 february 2010 snea...       5      2
#
#        Quarter  Year                       Branch  \
# 0            2  2019         Disneyland Hong Kong
# 1            2  2019         Disneyland Hong Kong
# 2            2  2019         Disneyland Hong Kong
# 3            2  2019         Disneyland Hong Kong
# 4            2  2019         Disneyland Hong Kong
# ...        ...   ...                          ...
# 90875        1  2010  Universal Studios Singapore
# 90876        1  2010  Universal Studios Singapore
# 90877        1  2010  Universal Studios Singapore
# 90878        1  2010  Universal Studios Singapore
# 90879        1  2010  Universal Studios Singapore
#
#        Monthly % of Positive Reviews  Monthly % of Mixed Reviews  \
# 0                          78.688525                   18.032787
# 1                          78.688525                   18.032787
# 2                          78.688525                   18.032787
# 3                          78.688525                   18.032787
# 4                          78.688525                   18.032787
# ...                              ...                         ...
# 90875                     100.000000                    0.000000
# 90876                     100.000000                    0.000000
# 90877                     100.000000                    0.000000
# 90878                     100.000000                    0.000000
# 90879                     100.000000                    0.000000
#
#        Monthly % of Negative Reviews
# 0                           3.278689
# 1                           3.278689
# 2                           3.278689
# 3                           3.278689
# 4                           3.278689
# ...                              ...
# 90875                       0.000000
# 90876                       0.000000
# 90877                       0.000000
# 90878                       0.000000
# 90879                       0.000000
#
# [90880 rows x 9 columns]

# %%
# Check for null values after the mereg
print(df_reviews.isnull().sum())
# Out:
# Review_Text                      0
# Rating                           0
# Month                            0
# Quarter                          0
# Year                             0
# Branch                           0
# Monthly % of Positive Reviews    0
# Monthly % of Mixed Reviews       0
# Monthly % of Negative Reviews    0
# dtype: int64

# %% [markdown]
# # **Park Attendance Dataset**
# # Extract

# %%
# Loading the data 
# (We manually compiled this data ourselves with the goal of using the data
# for data for this project, so it is imported clean).
url='https://drive.google.com/file/d/1m3_DJbGPaYLTtgtfVB0k9Mz5GY23toAH/view?usp=sharing'
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
df_att = pd.read_csv(url, encoding='UTF-8')

df_att
# Out:
#                         Branch  2006 Attendance (millions)  \
# 0        Disneyland California                       14.73
# 1             Disneyland Paris                       10.60
# 2         Disneyland Hong Kong                        5.20
# 3      Universal Studios Japan                        8.50
# 4    Universal Studios Florida                        6.00
# 5  Universal Studios Singapore                         NaN
#
#    2007 Attendance (millions)  2008 Attendance (millions)  \
# 0                      14.870                      14.720
# 1                      12.000                      12.688
# 2                       4.150                       4.500
# 3                       8.713                       8.300
# 4                       6.200                       6.231
# 5                         NaN                         NaN
#
#    2009 Attendance (millions)  2010 Attendance (millions)  \
# 0                       15.90                      15.980
# 1                       12.74                      10.500
# 2                        4.60                       5.200
# 3                        8.00                       8.160
# 4                        5.53                       5.925
# 5                         NaN                       2.000
#
#    2011 Attendance (millions)  2012 Attendance (millions)  \
# 0                      16.140                      15.960
# 1                      10.990                      11.200
# 2                       5.900                       6.700
# 3                       8.500                       9.700
# 4                       6.044                       6.195
# 5                       3.411                       3.480
#
#    2013 Attendance (millions)  2014 Attendance (millions)  \
# 0                      16.200                      16.770
# 1                      10.430                       9.940
# 2                       7.400                       7.600
# 3                      10.100                      11.800
# 4                       7.062                       8.263
# 5                       3.650                       3.840
#
#    2015 Attendance (millions)  2016 Attendance (millions)  \
# 0                      18.280                      17.940
# 1                      10.360                       8.400
# 2                       6.800                       6.100
# 3                      13.900                      14.500
# 4                       9.585                       9.998
# 5                       4.200                       4.100
#
#    2017 Attendance (millions)  2018 Attendance (millions)  \
# 0                      18.300                      18.660
# 1                       9.660                       9.843
# 2                       6.200                       6.700
# 3                      14.935                      14.300
# 4                      10.198                      10.708
# 5                       4.220                       4.400
#
#    2019 Attendance (millions)  2020 Attendance (millions)  \
# 0                      18.660                       3.670
# 1                       9.745                       2.620
# 2                       5.695                       1.700
# 3                      14.500                       4.901
# 4                      10.922                       4.096
# 5                       4.500                       1.098
#
#    2021 Attendance (millions)
# 0                       8.500
# 1                       3.500
# 2                       2.600
# 3                       5.500
# 4                       8.987
# 5                       1.200

# %% [markdown]
# # Dataset Integration (Enrich reviews with attendance information)

# %%
# Merge the attendance data into the review dataframe based on the branch and year
df_with_att = pd.merge(df_reviews, df_att, how='outer', on=['Branch'])

df_with_att
# Out:
#                                              Review_Text  Rating  Month  \
# 0      ever disneyland anywhere find disneyland hong ...       4      4
# 1      thanks god hot humid visiting park otherwise w...       4      4
# 2      hk disneyland great compact park unfortunately...       4      4
# 3      location city took around 1 hour kowlon kid li...       4      4
# 4      disney world disneyland anaheim tokyo disneyla...       3      4
# ...                                                  ...     ...    ...
# 90875  first visit universal studio theme park went p...       4      3
# 90876  finally visited singapore first theme park uni...       4      3
# 90877  visited first week soft opening unfortunately ...       4      3
# 90878  visited 3rd day soft opening ticket sale limit...       4      3
# 90879  group managed get ticket 16 february 2010 snea...       5      2
#
#        Quarter  Year                       Branch  \
# 0            2  2019         Disneyland Hong Kong
# 1            2  2019         Disneyland Hong Kong
# 2            2  2019         Disneyland Hong Kong
# 3            2  2019         Disneyland Hong Kong
# 4            2  2019         Disneyland Hong Kong
# ...        ...   ...                          ...
# 90875        1  2010  Universal Studios Singapore
# 90876        1  2010  Universal Studios Singapore
# 90877        1  2010  Universal Studios Singapore
# 90878        1  2010  Universal Studios Singapore
# 90879        1  2010  Universal Studios Singapore
#
#        Monthly % of Positive Reviews  Monthly % of Mixed Reviews  \
# 0                          78.688525                   18.032787
# 1                          78.688525                   18.032787
# 2                          78.688525                   18.032787
# 3                          78.688525                   18.032787
# 4                          78.688525                   18.032787
# ...                              ...                         ...
# 90875                     100.000000                    0.000000
# 90876                     100.000000                    0.000000
# 90877                     100.000000                    0.000000
# 90878                     100.000000                    0.000000
# 90879                     100.000000                    0.000000
#
#        Monthly % of Negative Reviews  2006 Attendance (millions)  ...  \
# 0                           3.278689                         5.2  ...
# 1                           3.278689                         5.2  ...
# 2                           3.278689                         5.2  ...
# 3                           3.278689                         5.2  ...
# 4                           3.278689                         5.2  ...
# ...                              ...                         ...  ...
# 90875                       0.000000                         NaN  ...
# 90876                       0.000000                         NaN  ...
# 90877                       0.000000                         NaN  ...
# 90878                       0.000000                         NaN  ...
# 90879                       0.000000                         NaN  ...
#
#        2012 Attendance (millions)  2013 Attendance (millions)  \
# 0                            6.70                        7.40
# 1                            6.70                        7.40
# 2                            6.70                        7.40
# 3                            6.70                        7.40
# 4                            6.70                        7.40
# ...                           ...                         ...
# 90875                        3.48                        3.65
# 90876                        3.48                        3.65
# 90877                        3.48                        3.65
# 90878                        3.48                        3.65
# 90879                        3.48                        3.65
#
#        2014 Attendance (millions)  2015 Attendance (millions)  \
# 0                            7.60                         6.8
# 1                            7.60                         6.8
# 2                            7.60                         6.8
# 3                            7.60                         6.8
# 4                            7.60                         6.8
# ...                           ...                         ...
# 90875                        3.84                         4.2
# 90876                        3.84                         4.2
# 90877                        3.84                         4.2
# 90878                        3.84                         4.2
# 90879                        3.84                         4.2
#
#        2016 Attendance (millions)  2017 Attendance (millions)  \
# 0                             6.1                        6.20
# 1                             6.1                        6.20
# 2                             6.1                        6.20
# 3                             6.1                        6.20
# 4                             6.1                        6.20
# ...                           ...                         ...
# 90875                         4.1                        4.22
# 90876                         4.1                        4.22
# 90877                         4.1                        4.22
# 90878                         4.1                        4.22
# 90879                         4.1                        4.22
#
#        2018 Attendance (millions)  2019 Attendance (millions)  \
# 0                             6.7                       5.695
# 1                             6.7                       5.695
# 2                             6.7                       5.695
# 3                             6.7                       5.695
# 4                             6.7                       5.695
# ...                           ...                         ...
# 90875                         4.4                       4.500
# 90876                         4.4                       4.500
# 90877                         4.4                       4.500
# 90878                         4.4                       4.500
# 90879                         4.4                       4.500
#
#        2020 Attendance (millions)  2021 Attendance (millions)
# 0                           1.700                         2.6
# 1                           1.700                         2.6
# 2                           1.700                         2.6
# 3                           1.700                         2.6
# 4                           1.700                         2.6
# ...                           ...                         ...
# 90875                       1.098                         1.2
# 90876                       1.098                         1.2
# 90877                       1.098                         1.2
# 90878                       1.098                         1.2
# 90879                       1.098                         1.2
#
# [90880 rows x 25 columns]

# %%
# Remove reviews that have the same Review Text.
df_with_att = df_with_att.drop_duplicates(subset = ['Review_Text'], keep = False)

# %% [markdown]
# # Generate Surrogate Keys

# %%
# Generate surrogate keys
df_with_att = df_with_att.reset_index(drop=True) # Reset index
df_with_att['Surrogate Key'] = range(1,len(df_with_att)+1)
df = df_with_att.reindex(columns=['Surrogate Key'] + list([c for c in df_with_att.columns if c!= 'Surrogate Key']))

df
# Out:
#        Surrogate Key                                        Review_Text  \
# 0                  1  ever disneyland anywhere find disneyland hong ...
# 1                  2  thanks god hot humid visiting park otherwise w...
# 2                  3  hk disneyland great compact park unfortunately...
# 3                  4  location city took around 1 hour kowlon kid li...
# 4                  5  disney world disneyland anaheim tokyo disneyla...
# ...              ...                                                ...
# 90841          90842  first visit universal studio theme park went p...
# 90842          90843  finally visited singapore first theme park uni...
# 90843          90844  visited first week soft opening unfortunately ...
# 90844          90845  visited 3rd day soft opening ticket sale limit...
# 90845          90846  group managed get ticket 16 february 2010 snea...
#
#        Rating  Month  Quarter  Year                       Branch  \
# 0           4      4        2  2019         Disneyland Hong Kong
# 1           4      4        2  2019         Disneyland Hong Kong
# 2           4      4        2  2019         Disneyland Hong Kong
# 3           4      4        2  2019         Disneyland Hong Kong
# 4           3      4        2  2019         Disneyland Hong Kong
# ...       ...    ...      ...   ...                          ...
# 90841       4      3        1  2010  Universal Studios Singapore
# 90842       4      3        1  2010  Universal Studios Singapore
# 90843       4      3        1  2010  Universal Studios Singapore
# 90844       4      3        1  2010  Universal Studios Singapore
# 90845       5      2        1  2010  Universal Studios Singapore
#
#        Monthly % of Positive Reviews  Monthly % of Mixed Reviews  \
# 0                          78.688525                   18.032787
# 1                          78.688525                   18.032787
# 2                          78.688525                   18.032787
# 3                          78.688525                   18.032787
# 4                          78.688525                   18.032787
# ...                              ...                         ...
# 90841                     100.000000                    0.000000
# 90842                     100.000000                    0.000000
# 90843                     100.000000                    0.000000
# 90844                     100.000000                    0.000000
# 90845                     100.000000                    0.000000
#
#        Monthly % of Negative Reviews  ...  2012 Attendance (millions)  \
# 0                           3.278689  ...                        6.70
# 1                           3.278689  ...                        6.70
# 2                           3.278689  ...                        6.70
# 3                           3.278689  ...                        6.70
# 4                           3.278689  ...                        6.70
# ...                              ...  ...                         ...
# 90841                       0.000000  ...                        3.48
# 90842                       0.000000  ...                        3.48
# 90843                       0.000000  ...                        3.48
# 90844                       0.000000  ...                        3.48
# 90845                       0.000000  ...                        3.48
#
#        2013 Attendance (millions)  2014 Attendance (millions)  \
# 0                            7.40                        7.60
# 1                            7.40                        7.60
# 2                            7.40                        7.60
# 3                            7.40                        7.60
# 4                            7.40                        7.60
# ...                           ...                         ...
# 90841                        3.65                        3.84
# 90842                        3.65                        3.84
# 90843                        3.65                        3.84
# 90844                        3.65                        3.84
# 90845                        3.65                        3.84
#
#        2015 Attendance (millions)  2016 Attendance (millions)  \
# 0                             6.8                         6.1
# 1                             6.8                         6.1
# 2                             6.8                         6.1
# 3                             6.8                         6.1
# 4                             6.8                         6.1
# ...                           ...                         ...
# 90841                         4.2                         4.1
# 90842                         4.2                         4.1
# 90843                         4.2                         4.1
# 90844                         4.2                         4.1
# 90845                         4.2                         4.1
#
#        2017 Attendance (millions)  2018 Attendance (millions)  \
# 0                            6.20                         6.7
# 1                            6.20                         6.7
# 2                            6.20                         6.7
# 3                            6.20                         6.7
# 4                            6.20                         6.7
# ...                           ...                         ...
# 90841                        4.22                         4.4
# 90842                        4.22                         4.4
# 90843                        4.22                         4.4
# 90844                        4.22                         4.4
# 90845                        4.22                         4.4
#
#        2019 Attendance (millions)  2020 Attendance (millions)  \
# 0                           5.695                       1.700
# 1                           5.695                       1.700
# 2                           5.695                       1.700
# 3                           5.695                       1.700
# 4                           5.695                       1.700
# ...                           ...                         ...
# 90841                       4.500                       1.098
# 90842                       4.500                       1.098
# 90843                       4.500                       1.098
# 90844                       4.500                       1.098
# 90845                       4.500                       1.098
#
#        2021 Attendance (millions)
# 0                             2.6
# 1                             2.6
# 2                             2.6
# 3                             2.6
# 4                             2.6
# ...                           ...
# 90841                         1.2
# 90842                         1.2
# 90843                         1.2
# 90844                         1.2
# 90845                         1.2
#
# [90846 rows x 26 columns]

# %%
# Checking the number of duplicated rows and rows with duplicate Review Texts.
duplicates = df[df.duplicated()]
review_text_duplicates = df[df.duplicated(subset=['Review_Text'])]
print("Number of entirely duplicated rows: " + str(duplicates.shape[0]))
print("Number of duplicate Review Texts: " + str(review_text_duplicates.shape[0]))
# Out:
# Number of entirely duplicated rows: 0
# Number of duplicate Review Texts: 0

# %%
# Check for null values
print(df.isnull().sum())
# Out:
# Surrogate Key                        0
# Review_Text                          0
# Rating                               0
# Month                                0
# Quarter                              0
# Year                                 0
# Branch                               0
# Monthly % of Positive Reviews        0
# Monthly % of Mixed Reviews           0
# Monthly % of Negative Reviews        0
# 2006 Attendance (millions)       15731
# 2007 Attendance (millions)       15731
# 2008 Attendance (millions)       15731
# 2009 Attendance (millions)       15731
# 2010 Attendance (millions)           0
# 2011 Attendance (millions)           0
# 2012 Attendance (millions)           0
# 2013 Attendance (millions)           0
# 2014 Attendance (millions)           0
# 2015 Attendance (millions)           0
# 2016 Attendance (millions)           0
# 2017 Attendance (millions)           0
# 2018 Attendance (millions)           0
# 2019 Attendance (millions)           0
# 2020 Attendance (millions)           0
# 2021 Attendance (millions)           0
# dtype: int64

# %% [markdown]
# # Load

# %%
# Convert the dataframe to a csv with the delimiter being a , symbol.
# We do not include in the index in the csv.
df.to_csv('staged_data.csv', sep=',', index=False)

# %%
# Download csv from Google Colab
files.download('staged_data.csv')
